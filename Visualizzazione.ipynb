# %%
#Importo le librerie necessarie
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

# %%
#Carico i dati
data = None
data_file = './DATA/Scuola_Lecce.csv'
with open(data_file,'r') as f:
    data = pd.read_csv(f)
    
data
# Out:
#    Provincia      Codice  ... latitudine longitudine
# 0      Lecce  LEEE00100C  ...  40.026395   18.129687
# 1      Lecce  LEEE00400X  ...  40.341210   18.178914
# 2      Lecce  LEEE00500Q  ...  40.366250   18.175863
# 3      Lecce  LEEE081009  ...  40.396453   18.132672
# 4      Lecce  LEIC80000E  ...  40.312729   18.194061
# ..       ...         ...  ...        ...         ...
# 73     Lecce  LEPS04000E  ...  40.168366   18.173829
# 74     Lecce  LEPS07000A  ...  40.361315   18.192678
# 75     Lecce  LESL03000R  ...  40.332191   18.143240
# 76     Lecce  LETD08000R  ...  40.346126   18.187569
# 77     Lecce  LETE010002  ...  40.360397   18.194838
#
# [78 rows x 14 columns]

# %%
# Individuo i valori medi per centrare la mappa
data['latitudine'] = data['latitudine'].astype('float')
data['longitudine'] = data['longitudine'].astype('float')
lat_M = data['latitudine'].mean()
lon_M = data['longitudine'].mean()

# %%
#Creo un oggetto mappa base
m=folium.Map(location=[lat_M, lon_M], zoom_starter=10)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
markercluster = MarkerCluster().add_to(m)

# %%
#Traccio gli indicatori sulla mappa

#Tooltip
tooltip = "Fare click per informazioni"

i=0
for i in range(0,len(data)):
    codice=data.at[i,'Codice']
    denominazione=data.at[i,'Denominazione']
    dirigente=data.at[i,'Dirigente']
    folium.Marker([data['latitudine'][i], data['longitudine'][i]],
            popup= f"Codice: {codice} Denominazione: {denominazione} Dirigente: {dirigente}",
            tooltip=tooltip,
            icon=folium.Icon(prefix='fa',icon='graduation-cap')).add_to(markercluster)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
